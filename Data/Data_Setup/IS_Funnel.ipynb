# %%
import pandas as pd

# %%
filename = "C:\\Users\\Admin\\Downloads\\Inside Sales Funnel  - ISRDetails.xlsx"
df1 = pd.read_excel(filename)

# %%
df = pd.DataFrame(df1)

# %%
df.head()
# Out:
#              Domain         Company Email Month Inside Sales\nConnect\nStage  \
# 0  privatecircle.co  Private Circle         Sep                      Meeting
# 1   blockonomics.co    Blockonomics         Sep                      Meeting
# 2       ssbsoft.com    SSB software         Sep                      Meeting
# 3       girmiti.com         Girmiti         Sep                      Meeting
# 4        hipbar.com          Hipbar         Sep                      Meeting
#
#   Sales Qualification Stage Sales Qualification Reason Qual Month Lead Owner  \
# 0                 Qualified                        NaN        Sep        Sid
# 1              DisQualified                   Laterals        NaN    Anirudh
# 2              DisQualified                     Budget        NaN        Sid
# 3              DisQualified        Tech Stack Mismatch        NaN    Anirudh
# 4              DisQualified                   Timeline        NaN        Sid
#
#                   Contact- Designation- Phone Number  \
# 0                    Krishna Skc Founder- 9940398894
# 1      shiva sitamraju (Founder & CEO) +919704534662
# 2   Magalingam Jayagopal (Founder & CEO)- 9940122555
# 3  Deric John\n Recruiting Manager\n Mob: +91-988...
# 4                       Prasanna Natarajan (Founder)
#
#                       Email                           Remarks by insight sales
# 0  krishna@privatecircle.co  Acc to Sid I just spoke to Vansh of Private Ci...
# 1     shiva@blockonomics.co  They Small company currently they are looking ...
# 2          mali@ssbsoft.com                    They have issue with the budget
# 3    deric.john@girmiti.com            They are on tech that we don't support.
# 4           pras@hipbar.com  Acc to Sid, the HR says their requirement are ...

# %%
Filename1='C:\\Users\\Admin\\Company.csv'
data = pd.read_csv(Filename1)

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#    Unnamed: 0          Domain          Company Segment Week VC Lead Owner  \
# 0           0      shuttl.com           Shuttl       X  w38  X    Shubham
# 1           1     godigit.com  Digit Insurance       X  w38  X      Rozer
# 2           2       swiggy.in           Swiggy       X  w38  X    Shubham
# 3           3  cleardekho.com       Cleardekho       X  w38  X    Shubham
# 4           4      zomato.com           Zomato       X  w38  X    Shubham
#
#     Location Region id_co
# 0        NCR  North  SNX0
# 1  Bengaluru  South  DBX1
# 2  Bengaluru  South  SBX2
# 3        NCR  North  CNX3
# 4        NCR  North  ZNX4

# %%
data = data[['Domain', 'id_co']]

# %%
data.head()
# Out:
#            Domain id_co
# 0      shuttl.com  SNX0
# 1     godigit.com  DBX1
# 2       swiggy.in  SBX2
# 3  cleardekho.com  CNX3
# 4      zomato.com  ZNX4

# %%
x = df.merge(data, left_on = 'Domain', right_on = 'Domain')

# %%
x.head()
# Out:
#              Domain           Company Email Month  \
# 0  privatecircle.co    Private Circle         Sep
# 1   blockonomics.co      Blockonomics         Sep
# 2       ssbsoft.com      SSB software         Sep
# 3       girmiti.com           Girmiti         Sep
# 4       girmiti.com  Girmiti Software        July
#
#   Inside Sales\nConnect\nStage Sales Qualification Stage  \
# 0                      Meeting                 Qualified
# 1                      Meeting              DisQualified
# 2                      Meeting              DisQualified
# 3                      Meeting              DisQualified
# 4                         Call              DisQualified
#
#   Sales Qualification Reason Qual Month Lead Owner  \
# 0                        NaN        Sep        Sid
# 1                   Laterals        NaN    Anirudh
# 2                     Budget        NaN        Sid
# 3        Tech Stack Mismatch        NaN    Anirudh
# 4                     Budget        NaN        Sid
#
#                   Contact- Designation- Phone Number  \
# 0                    Krishna Skc Founder- 9940398894
# 1      shiva sitamraju (Founder & CEO) +919704534662
# 2   Magalingam Jayagopal (Founder & CEO)- 9940122555
# 3  Deric John\n Recruiting Manager\n Mob: +91-988...
# 4       Sajesh Babu|  Associate AVP | +91 9986017324
#
#                       Email  \
# 0  krishna@privatecircle.co
# 1     shiva@blockonomics.co
# 2          mali@ssbsoft.com
# 3    deric.john@girmiti.com
# 4   sajesh.babu@girmiti.com
#
#                             Remarks by insight sales    id_co
# 0  Acc to Sid I just spoke to Vansh of Private Ci...  PBP3616
# 1  They Small company currently they are looking ...  BHF3138
# 2                    They have issue with the budget  SCM3700
# 3            They are on tech that we don't support.  GBX1018
# 4  Not interested. Budget too high for candidates...  GBX1018

# %%
Filename1='C:\\Users\\Admin\\IS_Funnel.csv'

# %%
IS_Funnel = x.to_csv(Filename1)
